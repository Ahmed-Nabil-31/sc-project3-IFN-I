# %%
# Preserve raw counts
adata.layers["counts"] = adata.X.copy()

# Normalize library size
sc.pp.normalize_total(adata, target_sum=1e4)

# Log-transform
sc.pp.log1p(adata)

# Store normalized/log-transformed expression
adata.raw = adata

# Select highly variable genes
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2500,
    batch_key="sample"
)

sc.pl.highly_variable_genes(adata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Preserve raw counts
# ----> 2 adata.layers["counts"] = adata.X.copy()
#       3
#       4 # Normalize library size
#       5 sc.pp.normalize_total(adata, target_sum=1e4)
#
# NameError: name 'adata' is not defined

# %%
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
from pathlib import Path

sc.settings.verbosity = 3
sc.settings.set_figure_params(
    dpi=120,
    facecolor="white",
    frameon=False
)

# %%
adata = sc.read_h5ad(
    "../results/preprocessing/merged_qc_filtered.h5ad"
)

print(
    f"Loaded: {adata.n_obs:,} cells × {adata.n_vars:,} genes"
)
# Out:
# Loaded: 94,513 cells × 31,054 genes

# %%
# Preserve raw counts
adata.layers["counts"] = adata.X.copy()

# Normalize library size
sc.pp.normalize_total(adata, target_sum=1e4)

# Log-transform
sc.pp.log1p(adata)

# Store normalized/log-transformed expression
adata.raw = adata

# Select 2,500 highly variable genes
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2500,
    batch_key="sample"
)

sc.pl.highly_variable_genes(adata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Preserve raw counts
# ----> 2 adata.layers["counts"] = adata.X.copy()
#       3
#       4 # Normalize library size
#       5 sc.pp.normalize_total(adata, target_sum=1e4)
#
# NameError: name 'adata' is not defined
